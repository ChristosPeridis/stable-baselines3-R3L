# %%
import minigrid
from minigrid.wrappers import ImgObsWrapper
from stable_baselines3.common.torch_layers import MinigridFeaturesExtractor
from stable_baselines3.common.buffers import *
from stable_baselines3 import PPO
from torch import nn
import gymnasium as gym
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
policy_kwargs = dict(
    features_extractor_class=MinigridFeaturesExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

# %%
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.LLmodules.tfcl import Task_free_continual_learning

tfcl_instance = Task_free_continual_learning()

class EvaluateHardBufferCallback(BaseCallback):
    def __init__(self,  use_hard_buffer:bool, hard_buffer, xh, yh, *args, **kwargs):
        super().__init__(*args, **kwargs)
        # Create an instance of Task_free_continual_learning
        self.use_hard_buffer = use_hard_buffer
        self.hard_buffer = hard_buffer
        self.xh = xh
        self.yh = yh
        

    def _on_rollout_end(self) -> bool:
        # Call the evaluate_hard_buffer method through the tfcl_instance
        total_loss = self.tfcl_instance.evaluate_hard_buffer(self.use_hard_buffer, self.hard_buffer, self.xh, self.yh)
        return total_loss

class MASRegularizationCallback(BaseCallback):
    def __init__(self, total_loss, continual_learning, star_varibles, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.total_loss = total_loss
        self.continual_learning = continual_learning
        self.star_varibles = star_varibles

    def _on_rollout_end(self) -> bool:
        total_loss = self.tfcl_instance.MAS_regularization(self.total_loss, self.continual_learning, self.star_varibles)
        return total_loss

class SaveTrainingAccuracyCallback(BaseCallback):
    def __init__(self, use_hard_buffer, hard_buffer, x, y, xh, yh, recent_loss, hard_loss=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.use_hard_buffer = use_hard_buffer
        self.hard_buffer = hard_buffer
        self.x = x
        self.y = y
        self.xh = xh
        self.yh = yh
        self.recent_loss = recent_loss
        self.hard_loss = hard_loss

    def _on_rollout_end(self) -> bool:
        msg, losses, accuracy = self.tfcl_instance.save_training_accuracy(self.use_hard_buffer, self.hard_buffer, self.x, self.y, self.xh, self.yh, self.recent_loss, self.hard_loss)
        return msg, losses, accuracy
    
class update_loss_window_and_detect_peak_callback(BaseCallback):
    def __init__(self, first_train_loss, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.first_train_loss = first_train_loss

    def _on_rollout_end(self) -> bool:
        new_peak_detected, loss_window_mean, loss_window_variance = self.tfcl_instance.update_loss_window_and_detect_peak()
        return new_peak_detected, loss_window_mean, loss_window_variance
    
class UpdateImportanceWeightsCallback(BaseCallback):
    def __init__(self, continual_learning, new_peak_detected, loss_window_mean, loss_window_variance, hard_buffer, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.continual_learning = continual_learning
        self.new_peak_detected = new_peak_detected
        self.loss_window_mean = loss_window_mean
        self.loss_window_variance = loss_window_variance
        self.hard_buffer = hard_buffer
        
    def _on_rollout_end(self) -> bool:
        dict_val = self.tfcl_instance.update_importance_weights_and_variables()
        return True, dict_val

class UpdateHardBufferCallback(BaseCallback):
    def __init__(self, use_hard_buffer, recent_loss, hard_loss, xt, yt, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.use_hard_buffer = use_hard_buffer
        self.recent_loss = recent_loss
        self.hard_loss = hard_loss
        self.xt = xt
        self.yt = yt

    def _on_rollout_end(self) -> bool:
        self.tfcl_instance.update_hard_buffer()
        return True

class EvaluateTestAccuracyCallback(BaseCallback):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
    def _on_rollout_end(self) -> bool:
        msg, self.test_loss = self.tfcl_instance.evaluate_test_accuracy()
        return msg, self.test_loss

# %%
#total_losss
class SharedData:
    def __init__(self):
        self.data = {}

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList

# Initialize shared data
shared_data = SharedData()

# Initialize callbacks with shared data
callback1 = EvaluateHardBufferCallback(shared_data, ...)
callback2 = MASRegularizationCallback(shared_data, ...)
# Add more callbacks as needed

# Combine callbacks into a CallbackList
callback_list = CallbackList([callback1, callback2, ...])

# %%
env = gym.make("MiniGrid-Empty-16x16-v0", render_mode="rgb_array")
env = ImgObsWrapper(env)

# %%
model = PPO("CnnPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(2e5)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 408      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012974362 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -3.96       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00808     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 2.59e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 3           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016076269 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -3.94       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0449     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 2.71e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.023836093 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -6.24       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0243     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 5.04e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 5           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.024086874 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | -4.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0379      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 7.82e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.02e+03   |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 224        |
# |    iterations           | 6          |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01650593 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | -7.91      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0147    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 0.000153   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.02e+03   |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 219        |
# |    iterations           | 7          |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01367303 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | -4.79      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0223    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 1.35e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 8           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011399701 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -10.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00965    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.00084     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 9           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015710045 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -9.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0469      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.69e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 10          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009335422 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -0.613      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0272      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 3.71e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 11          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020709708 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.694      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0305     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 4.58e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.0241      |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 12          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008887146 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | -1.83       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00987    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00997    |
# |    value_loss           | 7.25e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.0222      |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 13          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009829003 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.00243    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 0.041       |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 14          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014309891 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | -4.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 6.13e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 0.0689      |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 15          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012025783 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.00681     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0376     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 964         |
# |    ep_rew_mean          | 0.0649      |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 16          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016133536 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.0663      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 941         |
# |    ep_rew_mean          | 0.0895      |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 17          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008805161 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | -6.46       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0474      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00749    |
# |    value_loss           | 9.54e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 916         |
# |    ep_rew_mean          | 0.115       |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 18          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015946308 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.0205      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 860         |
# |    ep_rew_mean          | 0.173       |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 19          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011048841 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.0191      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00158     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0081     |
# |    value_loss           | 0.00309     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 745         |
# |    ep_rew_mean          | 0.287       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 20          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010648353 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | -0.0023     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0231      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 0.00879     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 700         |
# |    ep_rew_mean          | 0.332       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 21          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010558108 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.0654      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00823     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00505    |
# |    value_loss           | 0.0217      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 608        |
# |    ep_rew_mean          | 0.422      |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 22         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01194135 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.112      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00918   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00916   |
# |    value_loss           | 0.011      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | 0.534       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 23          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012447425 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0225      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.025       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 0.726       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 24          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008273181 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00701     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.0286      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 0.909       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 25          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013637108 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0127      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 0.0252      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.7         |
# |    ep_rew_mean          | 0.952        |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 26           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0089006685 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0076      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0148      |
# |    value_loss           | 0.0276       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.1        |
# |    ep_rew_mean          | 0.964       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 27          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008121256 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00915    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 0.0181      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.1         |
# |    ep_rew_mean          | 0.968        |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 28           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0053252527 |
# |    clip_fraction        | 0.0884       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00732     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 0.00989      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.7         |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 29           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0050058886 |
# |    clip_fraction        | 0.0827       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.478        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00101      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00892     |
# |    value_loss           | 0.00662      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.3         |
# |    ep_rew_mean          | 0.972        |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 30           |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0059825387 |
# |    clip_fraction        | 0.086        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0131      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0085      |
# |    value_loss           | 0.00445      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.9        |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 31          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004337403 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00679     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00813    |
# |    value_loss           | 0.00386     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31           |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 32           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0037212903 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.406       |
# |    explained_variance   | 0.584        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00027     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00437     |
# |    value_loss           | 0.00329      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 33          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003693128 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 0.00368     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 34          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004877858 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.322      |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00399    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 0.00326     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.3        |
# |    ep_rew_mean          | 0.973       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 35          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007195251 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.33       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00374    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00414    |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.1        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 36          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003758747 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.323      |
# |    explained_variance   | 0.534       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00533    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 0.00341     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | 0.974       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 37          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012888258 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.288      |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00694    |
# |    value_loss           | 0.00337     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.4         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 38           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0083550075 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -3.52e-05    |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 0.00268      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.3       |
# |    ep_rew_mean          | 0.956      |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 39         |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.23468919 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.254     |
# |    explained_variance   | 0.589      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00563   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0356     |
# |    value_loss           | 0.00276    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61.9       |
# |    ep_rew_mean          | 0.944      |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 40         |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.05199962 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.903     |
# |    explained_variance   | -4.83      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.046     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0308    |
# |    value_loss           | 0.00076    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.1       |
# |    ep_rew_mean          | 0.932      |
# | time/                   |            |
# |    fps                  | 233        |
# |    iterations           | 41         |
# |    time_elapsed         | 359        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01088628 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.526     |
# |    explained_variance   | 0.052      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00559   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0137    |
# |    value_loss           | 0.00719    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 0.923       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 42          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004789087 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00891    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.00963     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43          |
# |    ep_rew_mean          | 0.962       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 43          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.022349006 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.401      |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32          |
# |    ep_rew_mean          | 0.972       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 44          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009773698 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00942    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00664     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.6        |
# |    ep_rew_mean          | 0.971       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 45          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.022315126 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00053     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 0.00432     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.9        |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 46          |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.046379477 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00834     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 0.00527     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | 0.972       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 47          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.016597899 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.249      |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0054      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.7         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 48           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0097028455 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.206       |
# |    explained_variance   | 0.599        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00715     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 0.00338      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 49           |
# |    time_elapsed         | 431          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0017143001 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.177       |
# |    explained_variance   | 0.594        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000989    |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 0.00285      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28           |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 50           |
# |    time_elapsed         | 442          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0012460748 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00469      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 0.00245      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.7         |
# |    ep_rew_mean          | 0.976        |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 51           |
# |    time_elapsed         | 451          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0013323454 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.134       |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00105      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 0.00224      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28          |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 52          |
# |    time_elapsed         | 461         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005235515 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000853    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 0.00223     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 53          |
# |    time_elapsed         | 471         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.001354251 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00768    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.1         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 54           |
# |    time_elapsed         | 479          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0026413887 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0909      |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00104      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000759    |
# |    value_loss           | 0.00221      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.4        |
# |    ep_rew_mean          | 0.976       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 55          |
# |    time_elapsed         | 491         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.002764286 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0822     |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 31.2         |
# |    ep_rew_mean          | 0.973        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 81           |
# |    time_elapsed         | 721          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0016068018 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.152       |
# |    explained_variance   | 0.518        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e-05     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 0.00336      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.2         |
# |    ep_rew_mean          | 0.974        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 82           |
# |    time_elapsed         | 730          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0063725226 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.138       |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0049      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00495     |
# |    value_loss           | 0.0042       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.4         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 83           |
# |    time_elapsed         | 739          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0016017215 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.133       |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00169     |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 0.00253      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.8         |
# |    ep_rew_mean          | 0.976        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 84           |
# |    time_elapsed         | 748          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0007242997 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0116      |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.000875    |
# |    value_loss           | 0.00278      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.5         |
# |    ep_rew_mean          | 0.976        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 85           |
# |    time_elapsed         | 757          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0031690113 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0979      |
# |    explained_variance   | 0.606        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00339      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 0.00227      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28           |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 86           |
# |    time_elapsed         | 765          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0038674432 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0754      |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00147      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.000962    |
# |    value_loss           | 0.00222      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.4         |
# |    ep_rew_mean          | 0.975        |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 87           |
# |    time_elapsed         | 773          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0014330208 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0642      |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000876     |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 0.00327      |
# |    value_loss           | 0.00255      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.4        |
# |    ep_rew_mean          | 0.976       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 88          |
# |    time_elapsed         | 785         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.010416493 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0728     |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00107    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 0.0022      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.8         |
# |    ep_rew_mean          | 0.976        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 89           |
# |    time_elapsed         | 793          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0039123157 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0684      |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00216     |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 0.00218      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.6         |
# |    ep_rew_mean          | 0.976        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 90           |
# |    time_elapsed         | 803          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0023368741 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0874      |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00042     |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 0.00209      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.3        |
# |    ep_rew_mean          | 0.976       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 91          |
# |    time_elapsed         | 812         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.009905865 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0464     |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -3.54e-05   |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.2       |
# |    ep_rew_mean          | 0.956      |
# | time/                   |            |
# |    fps                  | 229        |
# |    iterations           | 92         |
# |    time_elapsed         | 820        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.13923775 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.114     |
# |    explained_variance   | 0.611      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00481   |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.00299   |
# |    value_loss           | 0.00225    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61.4       |
# |    ep_rew_mean          | 0.944      |
# | time/                   |            |
# |    fps                  | 229        |
# |    iterations           | 93         |
# |    time_elapsed         | 828        |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.10882481 |
# |    clip_fraction        | 0.276      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.353     |
# |    explained_variance   | -6.87      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0333    |
# |    n_updates            | 920        |
# |    policy_gradient_loss | 0.0468     |
# |    value_loss           | 0.000608   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.8        |
# |    ep_rew_mean          | 0.932       |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 94          |
# |    time_elapsed         | 836         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.016221108 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00325     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00542     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.7        |
# |    ep_rew_mean          | 0.925       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 95          |
# |    time_elapsed         | 846         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.012178937 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00541    |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.1        |
# |    ep_rew_mean          | 0.96        |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 96          |
# |    time_elapsed         | 854         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.028928105 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.8        |
# |    ep_rew_mean          | 0.967       |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 97          |
# |    time_elapsed         | 862         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.026909329 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0095     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00997    |
# |    value_loss           | 0.00794     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.8        |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 98          |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.007077952 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.387      |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0145     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 0.00558     |
# -----------------------------------------
